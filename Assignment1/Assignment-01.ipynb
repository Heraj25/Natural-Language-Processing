# %%
import pandas as pd
import string as st
import re
import nltk
from nltk import PorterStemmer, WordNetLemmatizer
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\heraj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\heraj\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data = pd.read_csv(r"C:\Users\heraj\OneDrive\Desktop\Dataset (1).csv")
data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
data.shape
# Out:
# (50000, 2)

# %%
# Remove all punctuations from the text

def remove_punct(text):
    return ("".join([ch for ch in text if ch not in st.punctuation]))

# %%
data['removed_punc'] = data['review'].apply(lambda x: remove_punct(x))
data.head()
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                         removed_punc
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production br br The filmin...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically theres a family where a little boy J...
# 4  Petter Matteis Love in the Time of Money is a ...

# %%
# Convert text to lower case tokens. Here, split() is applied on white-spaces. 

def tokenize(text):
    text = re.split('\s+' ,text)
    return [x.lower() for x in text]

# %%
data['tokens'] = data['removed_punc'].apply(lambda msg : tokenize(msg))
data.head()
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                         removed_punc  \
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production br br The filmin...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically theres a family where a little boy J...
# 4  Petter Matteis Love in the Time of Money is a ...
#
#                                               tokens
# 0  [one, of, the, other, reviewers, has, mentione...
# 1  [a, wonderful, little, production, br, br, the...
# 2  [i, thought, this, was, a, wonderful, way, to,...
# 3  [basically, theres, a, family, where, a, littl...
# 4  [petter, matteis, love, in, the, time, of, mon...

# %%
# Remove tokens of length less than 3
def remove_small_words(text):
    return [x for x in text if len(x) > 3 ]

# %%
data['larger_tokens'] = data['tokens'].apply(lambda x : remove_small_words(x))
data.head()
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                         removed_punc  \
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production br br The filmin...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically theres a family where a little boy J...
# 4  Petter Matteis Love in the Time of Money is a ...
#
#                                               tokens  \
# 0  [one, of, the, other, reviewers, has, mentione...
# 1  [a, wonderful, little, production, br, br, the...
# 2  [i, thought, this, was, a, wonderful, way, to,...
# 3  [basically, theres, a, family, where, a, littl...
# 4  [petter, matteis, love, in, the, time, of, mon...
#
#                                        larger_tokens
# 0  [other, reviewers, mentioned, that, after, wat...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, this, wonderful, spend, time, summer...
# 3  [basically, theres, family, where, little, jak...
# 4  [petter, matteis, love, time, money, visually,...

# %%
# Remove stopwords.
def remove_stopwords(text):
    return [word for word in text if word not in nltk.corpus.stopwords.words('english')]

# %%
data['clean_tokens'] = data['larger_tokens'].apply(lambda x : remove_stopwords(x))
data.head()
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                         removed_punc  \
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production br br The filmin...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically theres a family where a little boy J...
# 4  Petter Matteis Love in the Time of Money is a ...
#
#                                               tokens  \
# 0  [one, of, the, other, reviewers, has, mentione...
# 1  [a, wonderful, little, production, br, br, the...
# 2  [i, thought, this, was, a, wonderful, way, to,...
# 3  [basically, theres, a, family, where, a, littl...
# 4  [petter, matteis, love, in, the, time, of, mon...
#
#                                        larger_tokens  \
# 0  [other, reviewers, mentioned, that, after, wat...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, this, wonderful, spend, time, summer...
# 3  [basically, theres, family, where, little, jak...
# 4  [petter, matteis, love, time, money, visually,...
#
#                                         clean_tokens
# 0  [reviewers, mentioned, watching, episode, youl...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, wonderful, spend, time, summer, week...
# 3  [basically, theres, family, little, jake, thin...
# 4  [petter, matteis, love, time, money, visually,...

# %%
# Apply stemming to get root words 
def stemming(text):
    ps = PorterStemmer()
    return [ps.stem(word) for word in text]

# %%
data['stem_words'] = data['clean_tokens'].apply(lambda wrd: stemming(wrd))
data.head()
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                         removed_punc  \
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production br br The filmin...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically theres a family where a little boy J...
# 4  Petter Matteis Love in the Time of Money is a ...
#
#                                               tokens  \
# 0  [one, of, the, other, reviewers, has, mentione...
# 1  [a, wonderful, little, production, br, br, the...
# 2  [i, thought, this, was, a, wonderful, way, to,...
# 3  [basically, theres, a, family, where, a, littl...
# 4  [petter, matteis, love, in, the, time, of, mon...
#
#                                        larger_tokens  \
# 0  [other, reviewers, mentioned, that, after, wat...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, this, wonderful, spend, time, summer...
# 3  [basically, theres, family, where, little, jak...
# 4  [petter, matteis, love, time, money, visually,...
#
#                                         clean_tokens  \
# 0  [reviewers, mentioned, watching, episode, youl...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, wonderful, spend, time, summer, week...
# 3  [basically, theres, family, little, jake, thin...
# 4  [petter, matteis, love, time, money, visually,...
#
#                                           stem_words
# 0  [review, mention, watch, episod, youll, hook, ...
# 1  [wonder, littl, product, film, techniqu, unass...
# 2  [thought, wonder, spend, time, summer, weekend...
# 3  [basic, there, famili, littl, jake, think, the...
# 4  [petter, mattei, love, time, money, visual, st...

# %%
# Apply lemmatization on tokens
def lemmatize(text):
    word_net = WordNetLemmatizer()
    return [word_net.lemmatize(word) for word in text]

# %%
data['lemma_words'] = data['clean_tokens'].apply(lambda x : lemmatize(x))
data.head()
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                         removed_punc  \
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production br br The filmin...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically theres a family where a little boy J...
# 4  Petter Matteis Love in the Time of Money is a ...
#
#                                               tokens  \
# 0  [one, of, the, other, reviewers, has, mentione...
# 1  [a, wonderful, little, production, br, br, the...
# 2  [i, thought, this, was, a, wonderful, way, to,...
# 3  [basically, theres, a, family, where, a, littl...
# 4  [petter, matteis, love, in, the, time, of, mon...
#
#                                        larger_tokens  \
# 0  [other, reviewers, mentioned, that, after, wat...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, this, wonderful, spend, time, summer...
# 3  [basically, theres, family, where, little, jak...
# 4  [petter, matteis, love, time, money, visually,...
#
#                                         clean_tokens  \
# 0  [reviewers, mentioned, watching, episode, youl...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, wonderful, spend, time, summer, week...
# 3  [basically, theres, family, little, jake, thin...
# 4  [petter, matteis, love, time, money, visually,...
#
#                                           stem_words  \
# 0  [review, mention, watch, episod, youll, hook, ...
# 1  [wonder, littl, product, film, techniqu, unass...
# 2  [thought, wonder, spend, time, summer, weekend...
# 3  [basic, there, famili, littl, jake, think, the...
# 4  [petter, mattei, love, time, money, visual, st...
#
#                                          lemma_words
# 0  [reviewer, mentioned, watching, episode, youll...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, wonderful, spend, time, summer, week...
# 3  [basically, there, family, little, jake, think...
# 4  [petter, matteis, love, time, money, visually,...

# %%
# Create sentences to get clean text as input for vectors

def return_sentences(tokens):
    return " ".join([word for word in tokens])

# %%
data['clean_text'] = data['lemma_words'].apply(lambda x : return_sentences(x))
data.head()
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                         removed_punc  \
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production br br The filmin...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically theres a family where a little boy J...
# 4  Petter Matteis Love in the Time of Money is a ...
#
#                                               tokens  \
# 0  [one, of, the, other, reviewers, has, mentione...
# 1  [a, wonderful, little, production, br, br, the...
# 2  [i, thought, this, was, a, wonderful, way, to,...
# 3  [basically, theres, a, family, where, a, littl...
# 4  [petter, matteis, love, in, the, time, of, mon...
#
#                                        larger_tokens  \
# 0  [other, reviewers, mentioned, that, after, wat...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, this, wonderful, spend, time, summer...
# 3  [basically, theres, family, where, little, jak...
# 4  [petter, matteis, love, time, money, visually,...
#
#                                         clean_tokens  \
# 0  [reviewers, mentioned, watching, episode, youl...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, wonderful, spend, time, summer, week...
# 3  [basically, theres, family, little, jake, thin...
# 4  [petter, matteis, love, time, money, visually,...
#
#                                           stem_words  \
# 0  [review, mention, watch, episod, youll, hook, ...
# 1  [wonder, littl, product, film, techniqu, unass...
# 2  [thought, wonder, spend, time, summer, weekend...
# 3  [basic, there, famili, littl, jake, think, the...
# 4  [petter, mattei, love, time, money, visual, st...
#
#                                          lemma_words  \
# 0  [reviewer, mentioned, watching, episode, youll...
# 1  [wonderful, little, production, filming, techn...
# 2  [thought, wonderful, spend, time, summer, week...
# 3  [basically, there, family, little, jake, think...
# 4  [petter, matteis, love, time, money, visually,...
#
#                                           clean_text
# 0  reviewer mentioned watching episode youll hook...
# 1  wonderful little production filming technique ...
# 2  thought wonderful spend time summer weekend si...
# 3  basically there family little jake think there...
# 4  petter matteis love time money visually stunni...
